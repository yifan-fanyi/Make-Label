# %%
d = {"california sister": "Adelpha californica", "gulf fritillary": "Agraulis vanillae", "behrs metalmark": "Apodemia virgulti", "variable dancer": "Argia fumipennis", "western pygmy blue": "Brephidium exilis", "monarch": "Danaus plexippus", "funereal duskywing": "Erynnis funeralis", "mournful duskywing": "Erynnis tristis", "el segundo blue": "Euphilotes battoides allyni", "northern white skipper": "Heliopetes ericetorum", "fiery skipper": "Hylephila phyleus", "acmon blue": "Icaricia acmon", "gray buckeye": "Junonia coenia", "marine blue": "Leptotes marina", "eufala skipper": "Lerodea eufala", "pine white": "Neophasia menapia", "mourning cloak": "Nymphalis antiopa", "woodland skipper": "Ochlodes sylvanoides", "giant swallowtail": "Papilio cresphontes", "western tiger swallowtail": "Papilio rutulus", "cloudless sulphur": "Phoebis sennae", "cabbage white": "Pieris rapae", "umber skipper": "Poanes melane", "checkered white": "Pontia protodice", "common checkered skipper": "Pyrgus communis", "gray hairstreak": "Strymon melinus", "red admiral": "Vanessa atalanta", "painted lady": "Vanessa cardui", "american lady": "Vanessa virginiensis", "western giant swallowtail": "Papilio rumiko", "large orange sulphur": "Phoebis agarithe", "lorquin\u2019s admiral": "Limenitis lorquini", "anise swallowtail": "Papilio zelicaon", "west coast lady": "Vanessa annabella", "sara orangetips": "Anthocharis sara", "yudai fd": "Papilio polytes", "ganju fd": "Papilio xuthus", "cai fd": "Pieris rapae", "dongfangcai fd": "Pieris canidia", "huanggou jd": "Polygonia c-aureum", "menglianyin yd": "Neope muirheadi", "cujiang hd": "Pseudozizeeria maha", "quwenzi hd": "Chilades pandava", "heimai jd": "Hestina assimilis", "liuzishan jd": "Apatura ilia", "western pondhawk": "Erythemis collocata", "spot winged glider": "Pantala hymenaea", "pacific forktail": "Ischnura cervula", "adelpha californica": "adelpha californica", "agraulis vanillae": "agraulis vanillae", "apodemia virgulti": "apodemia virgulti", "argia fumipennis": "argia fumipennis", "brephidium exilis": "brephidium exilis", "danaus plexippus": "danaus plexippus", "erynnis funeralis": "erynnis funeralis", "erynnis tristis": "erynnis tristis", "euphilotes battoides allyni": "euphilotes battoides allyni", "heliopetes ericetorum": "heliopetes ericetorum", "hylephila phyleus": "hylephila phyleus", "icaricia acmon": "icaricia acmon", "junonia coenia": "junonia coenia", "leptotes marina": "leptotes marina", "lerodea eufala": "lerodea eufala", "neophasia menapia": "neophasia menapia", "nymphalis antiopa": "nymphalis antiopa", "ochlodes sylvanoides": "ochlodes sylvanoides", "papilio cresphontes": "papilio cresphontes", "papilio rutulus": "papilio rutulus", "phoebis sennae": "phoebis sennae", "pieris rapae": "pieris rapae", "poanes melane": "poanes melane", "pontia protodice": "pontia protodice", "pyrgus communis": "pyrgus communis", "strymon melinus": "strymon melinus", "vanessa atalanta": "vanessa atalanta", "vanessa cardui": "vanessa cardui", "vanessa virginiensis": "vanessa virginiensis", "papilio rumiko": "papilio rumiko", "phoebis agarithe": "phoebis agarithe", "limenitis lorquini": "limenitis lorquini", "papilio zelicaon": "papilio zelicaon", "vanessa annabella": "vanessa annabella", "anthocharis sara": "anthocharis sara", "papilio polytes": "papilio polytes", "papilio xuthus": "papilio xuthus", "pieris canidia": "pieris canidia", "polygonia c-aureum": "polygonia c-aureum", "neope muirheadi": "neope muirheadi", "pseudozizeeria maha": "pseudozizeeria maha", "chilades pandava": "chilades pandava", "hestina assimilis": "hestina assimilis", "apatura ilia": "apatura ilia", "erythemis collocata": "erythemis collocata", "pantala hymenaea": "pantala hymenaea", "ischnura cervula": "ischnura cervula", "Nymphalis antiopa": "Nymphalis antiopa", "Morning Cloak": "140 \\fbox{\\begin{minipage}{1.6cm}\\fontsize{4}{5}\\selectfont\\centering \\textbf{\\textit{Agraulis vanillae}} \\\\ 2022.11.14 \\\\ Irvine \\\\ \\end{minipage}}", "Coenonympha california ssp.\u00a0california": "\\fbox{\\begin{minipage}{1.6cm}\\fontsize{4}{5}\\selectfont\\centering CA \\\\ \\end{minipage}}", "Erynnis propertius": "143 \\fbox{\\begin{minipage}{1.6cm}\\fontsize{4}{5}\\selectfont\\centering \\textbf{\\textit{Papilio rumiko}} \\\\ 2022.11.28 \\\\ Irvine \\\\ \\end{minipage}}", "140 \\fbox{\\begin{minipage}{1.6cm}\\fontsize{4}{5}\\selectfont\\centering \\textbf{\\textit{agraulis vanillae}} \\\\ 2022.11.14 \\\\ irvine \\\\ \\end{minipage}}": "140 \\fbox{\\begin{minipage}{1.6cm}\\fontsize{4}{5}\\selectfont\\centering \\textbf{\\textit{agraulis vanillae}} \\\\ 2022.11.14 \\\\ irvine \\\\ \\end{minipage}}", "\\fbox{\\begin{minipage}{1.6cm}\\fontsize{4}{5}\\selectfont\\centering ca \\\\ \\end{minipage}}": "\\fbox{\\begin{minipage}{1.6cm}\\fontsize{4}{5}\\selectfont\\centering ca \\\\ \\end{minipage}}", "143 \\fbox{\\begin{minipage}{1.6cm}\\fontsize{4}{5}\\selectfont\\centering \\textbf{\\textit{papilio rumiko}} \\\\ 2022.11.28 \\\\ irvine \\\\ \\end{minipage}}": "143 \\fbox{\\begin{minipage}{1.6cm}\\fontsize{4}{5}\\selectfont\\centering \\textbf{\\textit{papilio rumiko}} \\\\ 2022.11.28 \\\\ irvine \\\\ \\end{minipage}}", "sara orangetip": "Anthocharis sara", "ansie swallowtail": "Papilio zelicaon", "variable checkerspot": "Euphydryas chalcedona", "orange sulphur": "Colias eurytheme", "northern checkerspot": "Chlosyne palla", "common ringlet": "Coenonympha tullia", "pale swallowtail": "Papilio eurymedon", "large marble": "Euchloe ausonides", "common buckeye": "Junonia coenia", "euphydryas chalcedona": "euphydryas chalcedona", "colias eurytheme": "colias eurytheme", "chlosyne palla": "chlosyne palla", "coenonympha tullia": "coenonympha tullia", "papilio eurymedon": "papilio eurymedon", "euchloe ausonides": "euchloe ausonides", "militia crescent": "Phyciodes mylitta", "clouded yellow": "Colias croceus", "propertius duskywing": "Erynnis propertius", "annie swallowtail": "Papilio zelicaon", "phyciodes mylitta": "phyciodes mylitta", "colias croceus": "colias croceus", "erynnis propertius": "erynnis propertius", "lycaena xanthoides": "lycaena xanthoides", "flame skinmmer": "Libellula saturata", "black saddlebags": "Tramea lacerata", "mylitta crescent": "Phyciodes mylitta"}
nd = {}
for k in d.keys():
    if k.lower() == d[k].lower():
        print(k, d[k])
    else:
        nd[k.lower()] = d[k]
# Out:
# adelpha californica adelpha californica
# agraulis vanillae agraulis vanillae
# apodemia virgulti apodemia virgulti
# argia fumipennis argia fumipennis
# brephidium exilis brephidium exilis
# danaus plexippus danaus plexippus
# erynnis funeralis erynnis funeralis
# erynnis tristis erynnis tristis
# euphilotes battoides allyni euphilotes battoides allyni
# heliopetes ericetorum heliopetes ericetorum
# hylephila phyleus hylephila phyleus
# icaricia acmon icaricia acmon
# junonia coenia junonia coenia
# leptotes marina leptotes marina
# lerodea eufala lerodea eufala
# neophasia menapia neophasia menapia
# nymphalis antiopa nymphalis antiopa
# ochlodes sylvanoides ochlodes sylvanoides
# papilio cresphontes papilio cresphontes
# papilio rutulus papilio rutulus
# phoebis sennae phoebis sennae
# pieris rapae pieris rapae
# poanes melane poanes melane
# pontia protodice pontia protodice
# pyrgus communis pyrgus communis
# strymon melinus strymon melinus
# vanessa atalanta vanessa atalanta
# ...

# %%
nd = sorted(nd)     
print(nd)
# Out:
# ['acmon blue', 'american lady', 'anise swallowtail', 'annie swallowtail', 'ansie swallowtail', 'behrs metalmark', 'black saddlebags', 'cabbage white', 'cai fd', 'california sister', 'checkered white', 'clouded yellow', 'cloudless sulphur', 'coenonympha california ssp.\xa0california', 'common buckeye', 'common checkered skipper', 'common ringlet', 'cujiang hd', 'dongfangcai fd', 'el segundo blue', 'erynnis propertius', 'eufala skipper', 'fiery skipper', 'flame skinmmer', 'funereal duskywing', 'ganju fd', 'giant swallowtail', 'gray buckeye', 'gray hairstreak', 'gulf fritillary', 'heimai jd', 'huanggou jd', 'large marble', 'large orange sulphur', 'liuzishan jd', 'lorquin’s admiral', 'marine blue', 'menglianyin yd', 'militia crescent', 'monarch', 'morning cloak', 'mournful duskywing', 'mourning cloak', 'mylitta crescent', 'northern checkerspot', 'northern white skipper', 'orange sulphur', 'pacific forktail', 'painted lady', 'pale swallowtail', 'pine white', 'propertius duskywing', 'quwen
# ...

# %%
d={'california sister': 'Adelpha californica', 
   'gulf fritillary': 'Agraulis vanillae', 
   'behrs metalmark': 'Apodemia virgulti', 
   'variable dancer': 'Argia fumipennis',
   'western pygmy blue': 'Brephidium exilis',
   'monarch': 'Danaus plexippus', 
   'funereal duskywing': 'Erynnis funeralis', 
   'mournful duskywing': 'Erynnis tristis', 
   'el segundo blue': 'Euphilotes battoides allyni', 
   'northern white skipper': 'Heliopetes ericetorum', 
   'fiery skipper': 'Hylephila phyleus', 
   'acmon blue': 'Icaricia acmon', 
   'common buckeye': 'Junonia coenia', 
   'marine blue': 'Leptotes marina', 
   'eufala skipper': 'Lerodea eufala', 
   'pine white': 'Neophasia menapia', 
   'mourning cloak': 'Nymphalis antiopa', 
   'woodland skipper': 
   'Ochlodes sylvanoides', 
   'giant swallowtail': 'Papilio cresphontes', 
   'western tiger swallowtail': 'Papilio rutulus', 
   'cloudless sulphur': 'Phoebis sennae', 
   'cabbage white': 'Pieris rapae', 
   'umber skipper': 'Poanes melane', 
   'checkered white': 'Pontia protodice', 
   'common checkered skipper': 'Pyrgus communis', 
   'gray hairstreak': 'Strymon melinus', 
   'red admiral': 'Vanessa atalanta', 
   'painted lady': 'Vanessa cardui', 
   'american lady': 'Vanessa virginiensis', 
   'western giant swallowtail': 'Papilio rumiko', 
   'large orange sulphur': 'Phoebis agarithe', 
   'lorquin’s admiral': 'Limenitis lorquini', 
   'anise swallowtail': 'Papilio zelicaon', 
   'west coast lady': 'Vanessa annabella', 
   'sara orangetips': 'Anthocharis sara', 
   'western pondhawk': 'Erythemis collocata', 
   'spot winged glider': 'Pantala hymenaea', 
   'pacific forktail': 'Ischnura cervula', 
   'sara orangetip': 'Anthocharis sara', 
   'ansie swallowtail': 'Papilio zelicaon',
   'variable checkerspot': 'Euphydryas chalcedona', 
   'orange sulphur': 'Colias eurytheme', 
   'northern checkerspot': 'Chlosyne palla', 
   'common ringlet': 'Coenonympha tullia', 
   'pale swallowtail': 'Papilio eurymedon', 
   'large marble': 'Euchloe ausonides', 
   'gray buckeye': 'Junonia grisea', 
   'clouded yellow': 'Colias croceus', 
   'propertius duskywing': 'Erynnis propertius', 
   'annie swallowtail': 'Papilio zelicaon', 
   'flame skinmmer': 'Libellula saturata', 
   'black saddlebags': 'Tramea lacerata', 
   'mylitta crescent': 'Phyciodes mylitta'}

# %%
dict(sorted(d.items(), key=lambda x: x[1]))
# Out:
# {'california sister': 'Adelpha californica',
#  'gulf fritillary': 'Agraulis vanillae',
#  'sara orangetips': 'Anthocharis sara',
#  'sara orangetip': 'Anthocharis sara',
#  'behrs metalmark': 'Apodemia virgulti',
#  'variable dancer': 'Argia fumipennis',
#  'western pygmy blue': 'Brephidium exilis',
#  'northern checkerspot': 'Chlosyne palla',
#  'common ringlet': 'Coenonympha tullia',
#  'clouded yellow': 'Colias croceus',
#  'orange sulphur': 'Colias eurytheme',
#  'monarch': 'Danaus plexippus',
#  'funereal duskywing': 'Erynnis funeralis',
#  'propertius duskywing': 'Erynnis propertius',
#  'mournful duskywing': 'Erynnis tristis',
#  'western pondhawk': 'Erythemis collocata',
#  'large marble': 'Euchloe ausonides',
#  'el segundo blue': 'Euphilotes battoides allyni',
#  'variable checkerspot': 'Euphydryas chalcedona',
#  'northern white skipper': 'Heliopetes ericetorum',
#  'fiery skipper': 'Hylephila phyleus',
#  'acmon blue': 'Icaricia acmon',
# ...

# %%
d={'california sister': 'Adelpha californica',
 'gulf fritillary': 'Agraulis vanillae',
 'sara orangetip': 'Anthocharis sara',
 'behrs metalmark': 'Apodemia virgulti',
 'variable dancer': 'Argia fumipennis',
 'western pygmy blue': 'Brephidium exilis',
 'northern checkerspot': 'Chlosyne palla',
 'common ringlet': 'Coenonympha tullia',
 'clouded yellow': 'Colias croceus',
 'orange sulphur': 'Colias eurytheme',
 'monarch': 'Danaus plexippus',
 'funereal duskywing': 'Erynnis funeralis',
 'propertius duskywing': 'Erynnis propertius',
 'mournful duskywing': 'Erynnis tristis',
 'western pondhawk': 'Erythemis collocata',
 'large marble': 'Euchloe ausonides',
 'el segundo blue': 'Euphilotes battoides allyni',
 'variable checkerspot': 'Euphydryas chalcedona',
 'northern white skipper': 'Heliopetes ericetorum',
 'fiery skipper': 'Hylephila phyleus',
 'acmon blue': 'Icaricia acmon',
 'pacific forktail': 'Ischnura cervula',
 'common buckeye': 'Junonia coenia',
 'gray buckeye': 'Junonia grisea',
 'marine blue': 'Leptotes marina',
 'eufala skipper': 'Lerodea eufala',
 'flame skinmmer': 'Libellula saturata',
 'lorquin’s admiral': 'Limenitis lorquini',
 'pine white': 'Neophasia menapia',
 'mourning cloak': 'Nymphalis antiopa',
 'woodland skipper': 'Ochlodes sylvanoides',
 'spot winged glider': 'Pantala hymenaea',
 'giant swallowtail': 'Papilio cresphontes',
 'pale swallowtail': 'Papilio eurymedon',
 'western giant swallowtail': 'Papilio rumiko',
 'western tiger swallowtail': 'Papilio rutulus',
 'anise swallowtail': 'Papilio zelicaon',
 'large orange sulphur': 'Phoebis agarithe',
 'cloudless sulphur': 'Phoebis sennae',
 'mylitta crescent': 'Phyciodes mylitta',
 'cabbage white': 'Pieris rapae',
 'umber skipper': 'Poanes melane',
 'checkered white': 'Pontia protodice',
 'common checkered skipper': 'Pyrgus communis',
 'gray hairstreak': 'Strymon melinus',
 'black saddlebags': 'Tramea lacerata',
 'west coast lady': 'Vanessa annabella',
 'red admiral': 'Vanessa atalanta',
 'painted lady': 'Vanessa cardui',
 'american lady': 'Vanessa virginiensis'}
import json
with open('name.json', 'w') as f:
    json.dump(d, f)
